# %%
a=int(input("enter the first number:"))
b=int(input("enter the first number:"))
sum=a+b
sub=a-b
mul=a*b
div=a/b
print("sum",sum)
print("sub",sub)
print("mul",mul)
print("div",div)
# Out:
# enter the first number:2
# enter the first number:5
# sum 7
# sub -3
# mul 10
# div 0.4

# %%
a=str(input("enter the name:"))
b=int(input("enter the age:"))
c=int(input("enter the salary:"))
print(a)
print(b)
print(c)
# Out:
# enter the name:manu
# enter the age:20
# enter the salary:20000
# manu
# 20
# 20000

# %%
print("hello")
# Out:
# hello

# %%
x=15
x=25
print(x)
# Out:
# 25

# %%
a=2
b=3
sum=a+b
print(sum)
# Out:
# 5

# %%
name="jhon"
print("name:",name)
# Out:
# name: jhon

# %%
b=float(input("enter the breadth:"))
l=float(input("enter the length:"))
area=b*l
print("area",area)
# Out:
# enter the breadth:23
# enter the length:33
# area 759.0

# %%
side=float(input("enter side area:"))
area=side*side
print("side of the area",area)
# Out:
# enter side area:5
# side of the area 25.0

# %%
a=int(input("enter the first number"))
b=int(input("enter the second number"))
if(a>b):
    print("largest number:",a)
    print("smallest number:",b) 
else:
    print("largest number:",b)
    print("smallest number:",a)
# Out:
# enter the first number54
# enter the second number34
# largest number: 54
# smallest number: 34

# %%
a=int(input("enter the number:"))
for i in range(1, 11):
    print(a, "x", i, "=", a * i)
# Out:
# enter the number:2
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20

# %%
n=int(input("enter the number:"))
for i in range(1,101):
    print(n, "x", i, "=", n * i)
# Out:
# enter the number:3
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
# 3 x 11 = 33
# 3 x 12 = 36
# 3 x 13 = 39
# 3 x 14 = 42
# 3 x 15 = 45
# 3 x 16 = 48
# 3 x 17 = 51
# 3 x 18 = 54
# 3 x 19 = 57
# 3 x 20 = 60
# 3 x 21 = 63
# 3 x 22 = 66
# 3 x 23 = 69
# 3 x 24 = 72
# 3 x 25 = 75
# 3 x 26 = 78
# 3 x 27 = 81
# 3 x 28 = 84
# 3 x 29 = 87
# 3 x 30 = 90
# 3 x 31 = 93
# 3 x 32 = 96
# 3 x 33 = 99
# 3 x 34 = 102
# 3 x 35 = 105
# 3 x 36 = 108
# 3 x 37 = 111
# 3 x 38 = 114
# 3 x 39 = 117
# 3 x 40 = 120
# 3 x 41 = 123
# 3 x 42 = 126
# 3 x 43 = 129
# 3 x 44 = 132
# 3 x 45 = 135
# 3 x 46 = 138
# 3 x 47 = 141
# 3 x 48 = 144
# 3 x 49 = 147
# 3 x 50 = 150
# 3 x 51 = 153
# 3 x 52 = 156
# 3 x 53 = 159
# 3 x 54 = 162
# 3 x 55 = 165
# 3 x 56 = 168
# 3 x 57 = 171
# 3 x 58 = 174
# 3 x 59 = 177
# 3 x 60 = 180
# 3 x 61 = 183
# 3 x 62 = 186
# 3 x 63 = 189
# 3 x 64 = 192
# 3 x 65 = 195
# 3 x 66 = 198
# 3 x 67 = 201
# 3 x 68 = 204
# 3 x 69 = 207
# 3 x 70 = 210
# 3 x 71 = 213
# 3 x 72 = 216
# 3 x 73 = 219
# 3 x 74 = 222
# 3 x 75 = 225
# 3 x 76 = 228
# 3 x 77 = 231
# 3 x 78 = 234
# 3 x 79 = 237
# 3 x 80 = 240
# 3 x 81 = 243
# 3 x 82 = 246
# 3 x 83 = 249
# 3 x 84 = 252
# 3 x 85 = 255
# 3 x 86 = 258
# 3 x 87 = 261
# 3 x 88 = 264
# 3 x 89 = 267
# 3 x 90 = 270
# 3 x 91 = 273
# 3 x 92 = 276
# 3 x 93 = 279
# 3 x 94 = 282
# 3 x 95 = 285
# 3 x 96 = 288
# 3 x 97 = 291
# 3 x 98 = 294
# 3 x 99 = 297
# 3 x 100 = 300

# %%
base=float(input("enter the base:"))
height=float(input("enter the height:"))
area=0.5 * base * height
print("area of triangle=",area)
# Out:
# enter the base:5
# enter the height:7
# area of triangle= 17.5

# %%
a=int(input("enter first no"))
b=int(input("enter second no"))
print("sum=",a+b)
print("sub",a-b)
print("mul",a*b)
# Out:
# enter first no10
# enter second no5
# sum= 15
# sub 5
# mul 50

# %%
a=12
print(a+5)
# Out:
# 17

# %%
principal=float(input("enter the principal amount: "))
years=float(input("enter the number of years: "))
rate=float(input("enter the rate of interest: "))
interest=(principal*years*rate)/100
print("simple interest",interest)
# Out:
# enter the principal amount: 12
# enter the number of years: 3
# enter the rate of interest: 12
# simple interest 4.32

# %%
num=int(input("enter an integer:"))
previous=num-1
next=num+1
print("previous number:",previous)
print("next number:",next)
# Out:
# enter an integer:2
# previous number: 1
# next number: 3

# %%
a=int(input("enter first no"))
b=int(input("enter second no"))
print("Quotient=",a//b)
print("Remainder",a%b)
# Out:
# enter first no5
# enter second no10
# Quotient= 0
# Remainder 5

# %%
r=float(input("enter the radius:"))
area=3.14*r*r
print("Area of the circle=",area)
# Out:
# enter the radius:4
# Area of the circle= 50.24

# %%
a=float(input("enter first no"))
b=float(input("enter second no"))
c=float(input("enter third no"))
average=(a+b+c)/3
print("average=",average)
# Out:
# enter first no2
# enter second no56
# enter third no23
# average= 27.0

# %%
celsius=float(input("enter tem in cesius:"))
fahrenheit=(celsius*9/5)+32
print("celsius of fahrenheit",fahrenheit)
# Out:
# enter tem in cesius:3
# celsius of fahrenheit 37.4

# %%
n=int(input("enter a number:"))
if n>100:
    print("number is greater than 100")
# Out:
# enter a number:500
# number is greater than 100

# %%
n=int(input("enter a number:"))
if n>100:
        print("number is greater than 100")
else: 
       print("number is not greater than 100")
# Out:
# enter a number:100
# number is greater than 100

# %%
n=int(input("enter a number:"))
if n%2==0:
        print("number is even")
else: 
       print("number is odd")
# Out:
# enter a number:1
# number is odd

# %%
a=int(input("enter a number:"))
b=int(input("enter a number:"))
if (a==b):
        print("number is equal")
else: 
       print("number is not equal")
# Out:
# enter a number:50
# enter a number:50
# number is equal

# %%
a=int(input("enter a number:"))
b=int(input("enter a number:"))
if (a>b):
        print(a,"is biggest")
else: 
       print(b,"is biggest")
# Out:
# enter a number:2
# enter a number:3
# 3 is biggest

# %%
age=int(input("enter a number:"))
if age>=18:
        print("eligble for vote")
else: 
       print("not eligble for vote")
# Out:
# enter a number:18
# eligble for vote

# %%
n=int(input("enter a number:"))
if n%5==0:
        print("divisible by 5")
else: 
       print("not divisible by 5")
# Out:
# enter a number:25
# divisible by 5

# %%
n=int(input("enter a number:"))
if n>0:
    print("positive")
else:
    print("negative")
# Out:
# enter a number:-2
# negative

# %%
mark=int(input("enter mark:"))
if mark>=90:
    print("A grade")
elif mark>=75:
    print("B grade")
elif mark>=50:
    print("C grade")
else:
    print("failed")
# Out:
# enter mark:35
# failed

# %%
n=int(input("enter a number:"))
if n>0:
    print("positive")
elif n<0:
    print("negative")
else:
    print("zero")
# Out:
# enter a number:3
# positive

# %%
a=int(input("enter first number:"))
b=int(input("enter second number:"))
c=int(input("enter third number:"))
if a>b and a>c:
    print("a is biggest")
elif a>b and a>c:
    print("b is biggest")
else:
    print("c is biggest")
# Out:
# enter first number:3
# enter second number:5
# enter third number:8
# c is biggest

# %%
age=int(input("enter the age"))
if age<13:
    print("child")
elif age<18:
    print("Teenage")
else:
    print("Adult")
# Out:
# enter the age15
# Teenage

# %%
Day=int(input("enter day number(1-7):"))
if Day==1:
    print("monday")
elif Day==2:
    print("tuesday")
elif Day==3:
    print("wednsday")
elif Day==4:
    print("thursday")
elif Day==5:
    print("friday")
elif Day==6:
    print("saturday")
elif Day==7:
    print("sunday")
else:
    print("invalid day number")
# Out:
# enter day number(1-7):4
# thursday

# %%
month=int(input("enter the month number(1-12):"))
if month==1:
    print("jan")
elif month==2:
    print("feb")
elif month==3:
    print("march")
elif month==4:
    print("april")
elif month==5:
    print("may")
elif month==6:
    print("june")
elif month==7:
    print("july")
elif month==8:
    print("aug")
elif month==9:
    print("sep")
elif month==10:
    print("oct")
elif month==11:
    print("nov")
elif month==12:
    print("dec")
else:
    print("invalid month number")
# Out:
# enter the month number(1-12):11
# nov

# %%
number = int(input("Enter a number: "))

if number % 3 == 0 and number % 5 == 0:
    print("The number is divisible by both 3 and 5.")
elif number % 3 == 0:
    print("The number is divisible by 3.")
elif number % 5 == 0:
    print("The number is divisible by 5.")
else:
    print("The number is not divisible by 3 or 5.")
# Out:
# Enter a number: 5
# The number is divisible by 5.

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a > b and a > c:
    print("Largest number is:", a)
elif b > a and b > c:
    print("Largest number is:", b)
else:
    print("Largest number is:", c)
# Out:
# Enter first number: 77
# Enter second number: 778
# Enter third number: 754
# Largest number is: 778

# %%
n=int(input("enter a number"))

if n%7==0:
    print("the number is divisible by 7")
else:
    print(" the number is not divisble by 7")
# Out:
# enter a number49
# the number is divisible by 7

# %%
c=input("enter a character")
vowels ="aeiouAEIOU"
if c in vowels:
    print("it is a vowel")
else:
    print("it is not a vowel")
# Out:
# enter a charactera
# it is a vowel

# %%
age=int(input("enter the age"))
if age>=18:
    print("he is eligible for driving licence")
else:
    print(" he is not eligible for driving licence")
# Out:
# enter the age44
# he is eligible for driving licence

# %%
string1=input("enter the first string")
string2=input("enter the second string")
if string1==string2:
    print("both strings are equal")
else:
    print("both are not equal")
# Out:
# enter the first stringhdyudddcgdcilc
# enter the second stringdkccuodj
# both are not equal

# %%
amount=int(input("enter the number"))
if amount>=5000:
    print("he is eligible for discount")
else:
    print("he is not eligible for discount")
# Out:
# enter the number400
# he is not eligible for discount

# %%
n=int(input("enter a number"))
if n>=10 and n<=100:
    print("n lies btwn 10 to 100")
else:
    print("n does not lies btwn 10 to 100")
# Out:
# enter a number20
# n lies btwn 10 to 100

# %%
attendance=int(input("enter the attendance percentage"))
if attendance >=75:
    print("he is eligible for exam")
else:
    print(" he is not eligible for exam")
# Out:
# enter the attendance percentage33
#  he is not eligible for exam

# %%
cha = input("Enter an alphabet: ")

if cha >= 'A' and cha <= 'Z':
    print("It is an uppercase letter.")
elif cha >= 'a' and cha <= 'z':
    print("It is a lowercase letter.")
else:
    print("It is not an alphabet.")
# Out:
# Enter an alphabet: w
# It is a lowercase letter.

# %%
num = int(input("Enter a number: "))

if num >= 100 and num <= 999:
    print("It is a three-digit number.")
else:
    print("It is not a three-digit number.")
# Out:
# Enter a number: 33
# It is not a three-digit number.

# %%
data = float(input("Enter mobile data used in GB: "))

if data < 2:
    print("Low usage")
elif data <= 5:
    print("Moderate usage")
else:
    print("High usage")
# Out:
# Enter mobile data used in GB: 8.7
# High usage
