# %%
print(10+15)
# Out:
# 25

# %%
x=10
x=13
print(x)
# Out:
# 13

# %%
name="john"
print("name")
# Out:
# name

# %%
print("name:"+name)
# Out:
# name:john

# %%
a=30
b=70
c=a+b
print(c)
# Out:
# 100

# %%
name=input("enter the name:")
print(name)
# Out:
# enter the name:abhi
# abhi

# %%
num1=int(input("enter the first number:"))
num2=int(input("enter the second number:"))
sum=num1+num2
print(sum)
# Out:
# enter the first number:2
# enter the second number:4
# 6

# %%
num1=int(input("enter the first number:"))
num2=int(input("enter the second number:"))
sum=num1+num2
sub=num1-num2
mul=num1*num2
div=num1/num2
print(sum)
print(sub)
print(mul)
print(div)
# Out:
# enter the first number:2
# enter the second number:10
# 12
# -8
# 20
# 0.2

# %%
name=input("enter the name:")
age=int(input("enter age:"))
mark=float(input("enter mark:"))
print(name)
print(age)
print(mark)
# Out:
# enter the name:abhi
# enter age:18
# enter mark:54
# abhi
# 18
# 54.0

# %%
print("hello")
# Out:
# hello

# %%
a=[1];
b=[2];
c=[3];
print(a)
# Out:
# [1]

# %%
name=input("enter the name:")
age=int(input("enter the age:"))
salary=int(input("enter the salary:"))
print(name)
print(age)
print(salary)
# Out:
# enter the name:danish
# enter the age:22
# enter the salary:50000000000
# danish
# 22
# 50000000000

# %%
side=float(input("enter the side of the sqaure:"))
area=side*side
print("area of the sqaure:",area)
# Out:
# enter the side of the sqaure:5
# area of the sqaure: 25.0

# %%
base=float(input("enter the base:"))
hieght=float(input("enter the hieght:"))
area=base*hieght
print("area of the right angle triangle:",area)
# Out:
# enter the base:5
# enter the hieght:5
# area of the right angle triangle: 25.0

# %%
p=float(input("enter the principal amount:"))
t=int(input("enter the year: "))
r=float(input("enter the rate of intrest:"))
si =(p*t*r)/100
print("simple intrest:",si)
# Out:
# enter the principal amount:20
# enter the year: 5
# enter the rate of intrest:8
# simple intrest: 8.0

# %%
num=int(input("enter an integer:"))
previous=num-1
next=num+1
print("previous number:", previous)
print("next number:",next)
# Out:
# enter an integer:20
# previous number: 19
# next number: 21

# %%
a=int(input("enter the first integer:"))
b=int(input("enter the second integer:"))
sum=a+b
difference=a-b
product=a*b
print("sum:",sum)
print("difference:",difference)
print("product:",product)
# Out:
# enter the first integer:4
# enter the second integer:5
# sum: 9
# difference: -1
# product: 20

# %%
a=int(input("enter the first number:"))
b=int(input("enter the second number:"))
quotient=a//b
reminder=a%b
print("quotient:",quotient)
print("reminder:",reminder)
# Out:
# enter the first number:12
# enter the second number:15
# quotient: 0
# reminder: 12

# %%
r=float(input("enter the radius of the circle:"))
area=3.14*r*r
print("area:",area)
# Out:
# enter the radius of the circle:5
# area: 78.5

# %%
a=float(input("enter the first no:"))
b=float(input("enter the second number:"))
c=float(input("enter the third number:"))
avarage=(a+b+c)/3
print("avarage:",avarage)
# Out:
# enter the first no:3
# enter the second number:4
# enter the third number:5
# avarage: 4.0

# %%
celsius=float(input("enter temp in celsius:"))
fahrenhiet=(celsius*9/5)+32
print("celsius of fahrenhiet:",fahrenhiet)
# Out:
# enter temp in celsius:5
# celsius of fahrenhiet: 41.0

# %%
n=int(input("enter a number:"))
if n>100:
    print("number is greater than 100")
else:
    print("number is not greater than 100")
# Out:
# enter a number:6
# number is not greater than 100

# %%
n=int(input("enter a number:"))
if n>=0:
    print("a positive number:")
else:
    print("a negative number:")
# Out:
# enter a number:4
# a positive number:

# %%
n=int(input("enter a number:"))
if n%2==0:
    print("is an even number:")
else:
    print("is an odd number:")
# Out:
# enter a number:9
# is an odd number:

# %%
a=int(input("enter the first number:"))
b=int(input("enter the second number:"))
if a==b:
    print("two numbers are equal")
else:
    print("two numbers are not equal")
# Out:
# enter the first number:8
# enter the second number:87
# two numbers are not equal

# %%
a=int(input("enter the 1st number"))
b=int(input("enter the 2nd number"))
if a<b:
    print("b is large")
else:
    print("a is large")
# Out:
# enter the 1st number10
# enter the 2nd number344
# b is large

# %%
age=int(input("enter a number"))
if age>=18:
    print(" he is eligible for vote")
else:
    print("not eligible for vote")
# Out:
# enter a number99
#  he is eligible for vote

# %%
n=int(input("enter a number"))
if n%5==0:
    print("is divisible by 5")
else:
    print("not divible by 5")
# Out:
# enter a number99
# not divible by 5

# %%
mark=int(input("enter mark"))
if mark>=90:
     print("a grade")
elif mark>=75:
    print("b grade")
elif mark>=50:
    print("c grade")
else:
    print("fail")
# Out:
# enter mark60
# c grade

# %%
n=int(input("enter a number"))
if n>0:
    print("is a postive no:")
elif n<0:
    print("is a negative no:")
else:
    print("is zero")
# Out:
# enter a number67
# is a postive no:

# %%
age=int(input("enter the age"))
if age<13:
    print("is child")
elif age<18:
    print("is teenage")
else:
    print("is adult")
# Out:
# enter the age77
# is adult

# %%
n=int(input("enter the number"))
if n==1:
    print("monday")
elif n==2:
    print("tuesday")
elif n==3:
    print("wed")
elif n==4:
    print("thus")
